# %% [markdown]
# # Análisis: COVID-19 en la República Argentina
# En esta investigación estaremos visualizando diferentes datos y métricas para entender el impacto del coronavirus en la Argentina, y las zonas más afectadas.

# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd

# %% [markdown]
# ## Lectura del archivo .csv

# %%
url = 'https://raw.githubusercontent.com/ezebinker/COVID-DatosGobAR/master/Covid19Casos.csv'
df=pd.read_csv(url, sep=',', encoding='utf16')
df.head(5)
# Out:
#    id_evento_caso sexo  ...  residencia_departamento_id ultima_actualizacion
# 0          672064    M  ...                         274           2020-06-07
# 1          717629    F  ...                         623           2020-06-07
# 2          717926    F  ...                          12           2020-06-07
# 3          718029    F  ...                         441           2020-06-07
# 4          718055    F  ...                           0           2020-06-07
#
# [5 rows x 25 columns]
